# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.colors as colors
import numpy as np

# %%
df = pd.read_csv("../mumax-bashs/resonator/mz_t.out/table.txt", comment="#", delim_whitespace=True)

# %%
df.columns = [
    "t (s)",
    "mx ()",
    "my ()",
    "mz ()",
    "m_x ()",
    "m_y ()",
    "m_z ()",
    "m_x.region1 ()",
    "m_y.region1 ()",
    "m_z.region1 ()",
    "m_x.region2 ()",
    "m_y.region2 ()",
    "m_z.region2 ()",
]

# %%
df
# Out:
#             t (s)     mx ()     my ()         mz ()    m_x ()    m_y ()  \
# 0    2.009296e-10  0.932554 -0.000053  6.662187e-05  0.932554 -0.000053
# 1    4.004026e-10  0.932553  0.000184 -8.193562e-05  0.932553  0.000184
# 2    6.005119e-10  0.932553 -0.000322  1.308520e-06  0.932553 -0.000322
# 3    8.015180e-10  0.932551  0.000359  1.596198e-04  0.932551  0.000359
# 4    1.000190e-09  0.932552 -0.000259 -3.084093e-04  0.932552 -0.000259
# ..            ...       ...       ...           ...       ...       ...
# 245  4.920081e-08  0.932552  0.000247 -8.774595e-05  0.932552  0.000247
# 246  4.940112e-08  0.932551 -0.000176  1.247186e-05  0.932551 -0.000176
# 247  4.960047e-08  0.932558  0.000097 -1.705149e-07  0.932558  0.000097
# 248  4.980092e-08  0.932553 -0.000066  3.073588e-05  0.932553 -0.000066
# 249  5.000000e-08  0.932553  0.000100 -6.586799e-05  0.932553  0.000100
#
#            m_z ()  m_x.region1 ()  m_y.region1 ()  m_z.region1 ()  \
# ...

# %%
plt.figure()
#plt.plot(df["t"], df["mx"], label="mx")
#plt.plot(df["t (s)"], df["m_z.region1 ()"], label="my")
plt.plot(df["t (s)"], df["m_z.region2 ()"], label="mz")
plt.xlabel("Time (s)")
plt.ylabel("Magnetization")
plt.legend()
plt.show()

# %%
import discretisedfield as df

# %%
vtkfilename = "../mumax-bashs/resonator/mz_t.out/m000004.ovf"
read_field = df.Field.from_file(vtkfilename)

# %%
mz = read_field.sel("z").array.squeeze()
plt.imshow(mz, cmap="seismic", origin="lower")
plt.colorbar(label="mz")
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.7575566172599792..1.0].

# %%
vtkfilename = "../mumax-bashs/resonator/mz_t.out/m000000.ovf"
read_field = df.Field.from_file(vtkfilename)

# %%
mz = read_field.sel("z").array.squeeze()
plt.imshow(mz, cmap="seismic", origin="lower")
plt.colorbar(label="mz")
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.999964714050293..1.0].
